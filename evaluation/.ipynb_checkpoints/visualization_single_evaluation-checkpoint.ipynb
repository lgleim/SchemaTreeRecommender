# %% [markdown]
# Compare 3 different files (Adapt paths!)

# %%
import seaborn as sns
import pandas as pd
from matplotlib.pyplot import figure
# load data sets
df_recommender = pd.read_csv("./typed.csv",encoding = "ISO-8859-1", skipinitialspace=True)
df_typed = pd.read_csv("./typed.csv",encoding = "ISO-8859-1", skipinitialspace=True)
df_typed_and_backoff = pd.read_csv("./standard.csv",encoding = "ISO-8859-1", skipinitialspace=True)

#extend information
df_recommender['Recommender']='Standard'
df_typed['Recommender']='Typed'
df_typed_and_backoff['Recommender']='Typed and Backoff'

#concat
df_combined = pd.concat([df_recommender, df_typed,df_typed_and_backoff])

#filter the aggregated columns
group = df_combined.columns[0]
df_combined = df_combined[df_combined[group] >=0]
print(df_combined[:10])

#plot
for column in df_combined:
    figure(num=None, figsize=(8, 3))
    sns.lineplot(x=group, y=column, hue="Recommender",data=df_combined, style ="Recommender")
    plt.show()
# Out:
#     numNonTypes  subjects  duration     mean  meanOfHits   median    stddev  \
# 1             0    356287    1.1828   8.2419      1.0012      1.0  268.9733
# 2             1    296415   15.6392  23.8257      7.5770      1.0  406.9212
# 3             2    501750   17.8670  32.8658      6.8947     36.0  510.8269
# 4             3    554426   17.9716  43.3576      5.6462      1.0  614.2263
# 5             4    836995   10.6932  40.1488      4.2738  10000.0  598.4760
# 6             5   1481065    5.8885  29.6444      2.9079      1.0  516.6893
# 7             6   1680740    4.8899  30.8008      2.8806      1.5  527.9046
# 8             7   1812322    3.7069  33.2999      2.8671      1.0  551.0228
# 9             8   2584144    2.2492  25.5682      2.2659      1.0  482.3237
# 10            9   2746637    1.7638  25.0611      2.2930      1.0  476.7381
#
#        top1     top5    top10     topL   recall  precision  precisionAtL  \
# ...
