# %%
#load the data and enrich with config information
import pandas as pd
import json
import matplotlib.pyplot as plt

# use LaTeX fonts in the plot
#plt.rc('text', usetex=True)
plt.rc('font', family='serif')


# df = pd.read_csv("./BatchTestResults-takeOneButType.csv",encoding = "ISO-8859-1", skipinitialspace=True)
# df2 = pd.read_csv("./BatchTestResults-takeMoreButCommon.csv",encoding = "ISO-8859-1", skipinitialspace=True)
df = pd.read_csv("./BatchTestResults-takeMoreButCommon-2.csv",encoding = "ISO-8859-1", skipinitialspace=True)
df['Config File'] = df.index

print(df[:10])

for i in df["Config File"]:
    with open('./configs/config_'+str(i)+'.json') as json_file:  
        data = json.load(json_file)
        df.at[i, 'backoff'] = data['Layers'][0]['Backoff']
        df.at[i, 'Condition'] = data['Layers'][0]['Condition']
        df.at[i, 'threshold'] = data['Layers'][0]['Threshold']
        df.at[i, 'threshold_float'] = data['Layers'][0]['ThresholdFloat']
        df.at[i, 'merger'] = data['Layers'][0]['Merger']
        df.at[i, 'splitter'] = data['Layers'][0]['Splitter']
        df.at[i, 'stepsize'] = data['Layers'][0]['Stepsize']
        df.at[i, 'Parallel Execution'] = data['Layers'][0]['ParallelExecutions']
        
#         #take precision values from other test
#         df.at[i, 'precisionAtL'] = df2.at[i, 'precisionAtL']
#         df.at[i, 'precision'] = df2.at[i, 'precision']
        
        if df.at[i, 'Condition'] == "tooUnlikelyRecommendationsCondition":
            df.at[i, 'Condition'] = "tooUnlikelyRecommendations"
        
        if df.at[i, 'backoff'] == 'splitProperty':
            df.at[i, 'Parallel Execution'] = 2
            df.at[i, 'Description'] = "Split Property (" +  df.at[i, 'splitter'] + " "+ df.at[i, 'merger']+")"
        if df.at[i, 'backoff'] == 'deleteLowFrequency':
             df.at[i, 'Description'] ="Delete Low Frequency ("+df.at[i, 'stepsize']+")"
                
df['Parallel Execution'] = df['Parallel Execution'].astype(int)

df["f1"]=2*df["precisionAtL"]*df["recall"]/(df["precisionAtL"]+df["recall"])

df.describe
# Out:
#    Config File  subjects  duration    mean  meanOfHits  median   stddev  \
# 0            0     40663   24.7532  3.9312      2.7205     1.0  27.1534
# 1            1     40663   24.9412  3.5964      2.9118     1.0  22.6400
# 2            2     40663   24.8525  3.9176      2.7069     1.0  27.1357
# 3            3     40663   24.9471  3.6002      2.9156     1.0  22.6152
# 4            4     40663   24.6782  5.9119      2.6832     1.0  41.5871
# 5            5     40663   24.7707  3.7543      2.9108     1.0  24.3377
# 6            6     40663   24.7925  5.5017      2.6888     1.0  39.0628
# 7            7     40663   24.8553  3.8081      2.8055     1.0  25.4850
# 8            8     40663   25.1147  5.2815      2.7011     1.0  37.5794
# 9            9     40663   24.8666  3.9310      2.7816     1.0  26.8071
#
#       top1     top5    top10     topL   recall  precision  precisionAtL
# 0  79.1358  93.3281  96.4243  87.5513  99.2945        NaN       67.9181
# 1  79.0129  93.1830  96.3529  87.4480  99.4026        NaN       67.8462
# 2  79.1776  93.3601  96.4316  87.5612  99.2946        NaN       67.9406
# 3  79.0129  93.1682  96.2988  87.4431  99.4035        NaN       67.8397
# 4  79.0006  93.0846  96.1169  87.3103  98.9046        NaN       67.8274
# 5  79.0301  93.1855  96.2693  87.3866  99.3485        NaN       67.8320
# 6  79.0129  93.1682  96.2005  87.3669  98.9632        NaN       67.8415
# 7  79.0547  93.2814  96.3702  87.5218  99.2801        NaN       67.8809
# 8  79.0079  93.1633  96.2054  87.3669  99.0006        NaN       67.8455
# 9  79.0448  93.2740  96.3874  87.5144  99.2379        NaN       67.8710
# <bound method NDFrame.describe of     Config File  subjects  duration    mean  meanOfHits  median   stddev  \
# 0             0     40663   24.7532  3.9312      2.7205     1.0  27.1534
# 1             1     40663   24.9412  3.5964      2.9118     1.0  22.6400
# 2             2     40663   24.8525  3.9176      2.7069     1.0  27.1357
# 3             3     40663   24.9471  3.6002      2.9156     1.0  22.6152
# 4             4     40663   24.6782  5.9119      2.6832     1.0  41.5871
# ..          ...       ...       ...     ...         ...     ...      ...
# 90           90     40663   42.3983  5.3715      2.9881     1.0  36.5249
# 91           91     40663   32.6321  3.9965      2.7859     1.0  27.3176
# 92           92     40663   48.6283  5.2646      3.0035     1.0  35.7269
# 93           93     40663   32.0010  3.9904      2.7676     1.0  27.3691
# 94           94     40663   55.3658  5.1454      3.0065     1.0  34.8540
#
#        top1     top5    top10  ...             backoff  \
# 0   79.1358  93.3281  96.4243  ...       splitProperty
# 1   79.0129  93.1830  96.3529  ...       splitProperty
# 2   79.1776  93.3601  96.4316  ...       splitProperty
# 3   79.0129  93.1682  96.2988  ...       splitProperty
# 4   79.0006  93.0846  96.1169  ...  deleteLowFrequency
# ..      ...      ...      ...  ...                 ...
# 90  78.7596  92.6493  95.7406  ...  deleteLowFrequency
# 91  79.0252  93.2100  96.3456  ...  deleteLowFrequency
# 92  78.7546  92.6813  95.7578  ...  deleteLowFrequency
# 93  79.0104  93.2125  96.3333  ...  deleteLowFrequency
# 94  78.7325  92.6592  95.7578  ...  deleteLowFrequency
#
#                      Condition  threshold  threshold_float merger  \
# 0        tooFewRecommendations        1.0              0.0    max
# 1        tooFewRecommendations        1.0              0.0    max
# 2        tooFewRecommendations        1.0              0.0    avg
# 3        tooFewRecommendations        1.0              0.0    avg
# 4        tooFewRecommendations        1.0              0.0
# ..                         ...        ...              ...    ...
# 90  tooUnlikelyRecommendations        3.0              0.1
# 91  tooUnlikelyRecommendations        3.0              0.1
# 92  tooUnlikelyRecommendations        3.0              0.1
# 93  tooUnlikelyRecommendations        3.0              0.1
# 94  tooUnlikelyRecommendations        3.0              0.1
#
#             splitter              stepsize  Parallel Execution  \
# 0    everySecondItem                                         2
# 1   twoSupportRanges                                         2
# 2    everySecondItem                                         2
# 3   twoSupportRanges                                         2
# 4                           stepsizeLinear                   1
# ..               ...                   ...                 ...
# 90                          stepsizeLinear                   4
# 91                    stepsizeProportional                   4
# 92                          stepsizeLinear                   5
# 93                    stepsizeProportional                   5
# 94                          stepsizeLinear                   6
#
#                                     Description         f1
# 0          Split Property (everySecondItem max)  80.662507
# 1         Split Property (twoSupportRanges max)  80.647379
# 2          Split Property (everySecondItem avg)  80.678406
# 3         Split Property (twoSupportRanges avg)  80.643083
# 4         Delete Low Frequency (stepsizeLinear)  80.469758
# ..                                          ...        ...
# 90        Delete Low Frequency (stepsizeLinear)  80.306850
# 91  Delete Low Frequency (stepsizeProportional)  80.553344
# 92        Delete Low Frequency (stepsizeLinear)  80.329890
# 93  Delete Low Frequency (stepsizeProportional)  80.577575
# 94        Delete Low Frequency (stepsizeLinear)  80.318272
#
# [95 rows x 24 columns]>

# %%
# seaborn visualization
import seaborn as sns

plt.figure(figsize=(15,25))
g = sns.relplot(x="recall", y="precisionAtL", hue="Description",style ="Description", size="Parallel Execution",
            sizes=(50, 200), alpha=.7,
            height=6, data=df)

#leg = g._legend
#leg.set_bbox_to_anchor([0.30,0.0])  # coordinates of lower left of bounding box
#leg._loc=8
#plt.subplots_adjust(bottom=0.5, right=0.6)
# plt.show()
plt.savefig("backoff_comp.pdf", bbox_inches='tight')

plt.figure(figsize=(15,25))
g = sns.relplot(x="recall", y="precisionAtL", hue="Condition", style="Condition", size="threshold",
            sizes=(50, 200), alpha=.2,
            height=6, data=df)

#leg = g._legend
#leg.set_bbox_to_anchor([0.7,0.3])  # coordinates of lower left of bounding box

#leg._loc=3
#plt.subplots_adjust(bottom=0, right=0.1)

# plt.show()
plt.savefig("condition_comp.pdf", bbox_inches='tight')

# %%
sns.stripplot(x="f1", y="Description", data=df, jitter=True, dodge=True, hue="Condition")

# %%
#g = sns.FacetGrid(df, row="Description", height=1, aspect=4, hue="Condition", margin_titles=True) # hue_kws={"marker": ["^", "v"]})
#g.map(plt.scatter, "f1", "threshold")
#g.add_legend()

f, axes = plt.subplots(6, 1, figsize=(11, 4), sharex=True, sharey=True)
markers = {1: r"$\mathbf{1}$", 2:"$\mathbf{2}$", 3:"$\mathbf{3}$", 4:"$\mathbf{4}$", 5:"$\mathbf{5}$", 6:"$\mathbf{6}$"}
marker_style = dict(linestyle=':', color='0.8', mec="None", markersize=15)

for ax, column in list(zip(axes.flat, sorted(set(df["Description"])))):
    sns.scatterplot(
        x="f1", 
        y="threshold", 
        hue="Condition",
        style="Parallel Execution",
        markers=markers,
        edgecolors='none',
        data=df[df["Description"]==column], 
        ax=ax,
        **marker_style
    )
    ax.get_legend().remove()
#     ax.set_title(column, fontsize=10, rotation=90, loc="left", horizontalalignment='right', verticalalignment='center',)
    ax.set_aspect('auto')
    ax.yaxis.set_label_position("right")
    ax.set_ylabel(column.replace(" (","\n")[:-1], rotation=0,
                  horizontalalignment='left', verticalalignment="center")

f.tight_layout()

f.text(-0.01, 0.54, 'threshold', va='center', rotation='vertical')

handles, labels = ax.get_legend_handles_labels()
#f.legend(handles, labels, loc='center left', bbox_to_anchor=(1.01, 0.46), borderaxespad=0.)
f.legend(handles[1:3], labels[1:3], loc='upper center', bbox_to_anchor=(0.42, 1.03), borderaxespad=0.,ncol=2)

plt.subplots_adjust(hspace=0.2)

plt.savefig('tex_demo.pdf',bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-141-3cc27a4a6e5a> in <module>
#      17         data=df[df["Description"]==column],
#      18         ax=ax,
# ---> 19         **marker_style
#      20     )
#      21     ax.get_legend().remove()
#
# ~/go/src/recommender/evaluation/jupyter/lib/python3.7/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1339         ax = plt.gca()
#    1340
# -> 1341     p.plot(ax, kwargs)
#    1342
#    1343     return ax
#
# ~/go/src/recommender/evaluation/jupyter/lib/python3.7/site-packages/seaborn/relational.py in plot(self, ax, kws)
#     877         # function will advance the axes property cycle.
#     878
# --> 879         scout = ax.scatter([], [], **kws)
#     880         s = kws.pop("s", scout.get_sizes())
#     881         c = kws.pop("c", scout.get_facecolors())
#
# ~/go/src/recommender/evaluation/jupyter/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/go/src/recommender/evaluation/jupyter/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4499                 )
#    4500         collection.set_transform(mtransforms.IdentityTransform())
# -> 4501         collection.update(kwargs)
#    4502
#    4503         if colors is None:
#
# ~/go/src/recommender/evaluation/jupyter/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# ~/go/src/recommender/evaluation/jupyter/lib/python3.7/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# ~/go/src/recommender/evaluation/jupyter/lib/python3.7/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     968                 if not callable(func):
#     969                     raise AttributeError('{!r} object has no property {!r}'
# --> 970                                          .format(type(self).__name__, k))
#     971                 return func(v)
#     972
#
# AttributeError: 'PathCollection' object has no property 'mfc'

# %%
# Out:
#     Config File  subjects  duration    mean  meanOfHits  median   stddev  \
# 4             4     40663   24.6782  5.9119      2.6832     1.0  41.5871
# 6             6     40663   24.7925  5.5017      2.6888     1.0  39.0628
# 8             8     40663   25.1147  5.2815      2.7011     1.0  37.5794
# 10           10     40663   25.3783  5.0742      2.7016     1.0  36.1862
# 12           12     40663   25.8503  4.9539      2.7036     1.0  35.3375
# 14           14     40663   26.4648  4.8444      2.7165     1.0  34.5135
# 20           20     40663   24.9557  5.9492      2.7206     1.0  41.6244
# 22           22     40663   25.3800  5.5327      2.7200     1.0  39.0903
# 24           24     40663   25.9151  5.3099      2.7418     1.0  37.5663
# 26           26     40663   26.5113  5.1408      2.7440     1.0  36.4138
# 28           28     40663   27.3578  5.0170      2.7425     1.0  35.5853
# 30           30     40663   28.3278  4.8833      2.7555     1.0  34.5597
# 36           36     40663   24.7091  5.9185      2.6898     1.0  41.6070
# 38           38     40663   24.9667  5.5113      2.6984     1.0  39.0760
# 40           40     40663   25.3089  5.2686      2.7127     1.0  37.4519
# 42           42     40663   25.8151  5.0937      2.7213     1.0  36.2420
# 44           44     40663   26.5653  4.9759      2.7257     1.0  35.3922
# 46           46     40663   27.3543  4.8526      2.7247     1.0  34.5298
# 52           52     40663   27.9633  6.1924      2.9408     1.0  41.9218
# 54           54     40663   31.3226  5.7876      2.9517     1.0  39.4253
# 56           56     40663   34.7002  5.5403      2.9612     1.0  37.8101
# 58           58     40663   38.4869  5.3626      2.9669     1.0  36.5926
# 60           60     40663   42.4869  5.2441      2.9706     1.0  35.7744
# 62           62     40663   46.8455  5.1247      2.9734     1.0  34.9349
# 68           68     40663   24.8387  5.9299      2.7013     1.0  41.6188
# 70           70     40663   25.1411  5.5289      2.7161     1.0  39.1023
# 72           72     40663   25.6971  5.2824      2.7266     1.0  37.4625
# 74           74     40663   26.8079  5.0890      2.7288     1.0  36.1521
# 76           76     40663   27.8453  4.9843      2.7465     1.0  35.3649
# 78           78     40663   29.6761  4.8544      2.7388     1.0  34.4793
# 84           84     40663   28.3108  6.2241      2.9727     1.0  41.9583
# 86           86     40663   32.7732  5.8079      2.9721     1.0  39.4312
# 88           88     40663   37.0313  5.5464      2.9796     1.0  37.7213
# 90           90     40663   42.3983  5.3715      2.9881     1.0  36.5249
# 92           92     40663   48.6283  5.2646      3.0035     1.0  35.7269
# 94           94     40663   55.3658  5.1454      3.0065     1.0  34.8540
#
#        top1     top5    top10  ...             backoff  \
# 4   79.0006  93.0846  96.1169  ...  deleteLowFrequency
# 6   79.0129  93.1682  96.2005  ...  deleteLowFrequency
# 8   79.0079  93.1633  96.2054  ...  deleteLowFrequency
# 10  79.0202  93.1977  96.2570  ...  deleteLowFrequency
# 12  79.0620  93.2150  96.2693  ...  deleteLowFrequency
# 14  79.0743  93.2199  96.2841  ...  deleteLowFrequency
# 20  78.9637  93.0699  96.0874  ...  deleteLowFrequency
# 22  78.9907  93.0772  96.1464  ...  deleteLowFrequency
# 24  79.0129  93.1338  96.1906  ...  deleteLowFrequency
# 26  79.0227  93.1461  96.2128  ...  deleteLowFrequency
# 28  79.0596  93.1904  96.2349  ...  deleteLowFrequency
# 30  79.0252  93.1805  96.2374  ...  deleteLowFrequency
# 36  79.0227  93.0600  96.1169  ...  deleteLowFrequency
# 38  79.0079  93.1092  96.1562  ...  deleteLowFrequency
# 40  79.0104  93.1559  96.2202  ...  deleteLowFrequency
# 42  79.0399  93.1609  96.2447  ...  deleteLowFrequency
# 44  79.0498  93.1855  96.2497  ...  deleteLowFrequency
# 46  79.0350  93.2125  96.2620  ...  deleteLowFrequency
# 52  78.8137  92.6715  95.7037  ...  deleteLowFrequency
# 54  78.8481  92.7133  95.7701  ...  deleteLowFrequency
# 56  78.8309  92.7231  95.7996  ...  deleteLowFrequency
# 58  78.8506  92.7625  95.8168  ...  deleteLowFrequency
# 60  78.8678  92.7920  95.8537  ...  deleteLowFrequency
# 62  78.8727  92.8289  95.8734  ...  deleteLowFrequency
# 68  78.9686  93.0404  96.1021  ...  deleteLowFrequency
# 70  78.9809  93.1018  96.1587  ...  deleteLowFrequency
# 72  78.9686  93.1068  96.1833  ...  deleteLowFrequency
# 74  78.9956  93.1510  96.2324  ...  deleteLowFrequency
# 76  78.9981  93.1584  96.2251  ...  deleteLowFrequency
# 78  79.0153  93.1855  96.2693  ...  deleteLowFrequency
# 84  78.7079  92.5411  95.6103  ...  deleteLowFrequency
# 86  78.7497  92.5977  95.6840  ...  deleteLowFrequency
# 88  78.7350  92.6149  95.6890  ...  deleteLowFrequency
# 90  78.7596  92.6493  95.7406  ...  deleteLowFrequency
# 92  78.7546  92.6813  95.7578  ...  deleteLowFrequency
# 94  78.7325  92.6592  95.7578  ...  deleteLowFrequency
#
#                      Condition  threshold  threshold_float merger splitter  \
# 4        tooFewRecommendations        1.0         0.000000
# 6        tooFewRecommendations        1.0         0.000000
# 8        tooFewRecommendations        1.0         0.000000
# 10       tooFewRecommendations        1.0         0.000000
# 12       tooFewRecommendations        1.0         0.000000
# 14       tooFewRecommendations        1.0         0.000000
# 20  tooUnlikelyRecommendations        1.0         0.033333
# 22  tooUnlikelyRecommendations        1.0         0.033333
# 24  tooUnlikelyRecommendations        1.0         0.033333
# 26  tooUnlikelyRecommendations        1.0         0.033333
# 28  tooUnlikelyRecommendations        1.0         0.033333
# 30  tooUnlikelyRecommendations        1.0         0.033333
# 36       tooFewRecommendations        2.0         0.000000
# 38       tooFewRecommendations        2.0         0.000000
# 40       tooFewRecommendations        2.0         0.000000
# 42       tooFewRecommendations        2.0         0.000000
# 44       tooFewRecommendations        2.0         0.000000
# 46       tooFewRecommendations        2.0         0.000000
# 52  tooUnlikelyRecommendations        2.0         0.066667
# 54  tooUnlikelyRecommendations        2.0         0.066667
# 56  tooUnlikelyRecommendations        2.0         0.066667
# 58  tooUnlikelyRecommendations        2.0         0.066667
# 60  tooUnlikelyRecommendations        2.0         0.066667
# 62  tooUnlikelyRecommendations        2.0         0.066667
# 68       tooFewRecommendations        3.0         0.000000
# 70       tooFewRecommendations        3.0         0.000000
# 72       tooFewRecommendations        3.0         0.000000
# 74       tooFewRecommendations        3.0         0.000000
# 76       tooFewRecommendations        3.0         0.000000
# 78       tooFewRecommendations        3.0         0.000000
# 84  tooUnlikelyRecommendations        3.0         0.100000
# 86  tooUnlikelyRecommendations        3.0         0.100000
# 88  tooUnlikelyRecommendations        3.0         0.100000
# 90  tooUnlikelyRecommendations        3.0         0.100000
# 92  tooUnlikelyRecommendations        3.0         0.100000
# 94  tooUnlikelyRecommendations        3.0         0.100000
#
#           stepsize  Parallel Execution                            Description  \
# 4   stepsizeLinear                   1  Delete Low Frequency (stepsizeLinear)
# 6   stepsizeLinear                   2  Delete Low Frequency (stepsizeLinear)
# 8   stepsizeLinear                   3  Delete Low Frequency (stepsizeLinear)
# 10  stepsizeLinear                   4  Delete Low Frequency (stepsizeLinear)
# 12  stepsizeLinear                   5  Delete Low Frequency (stepsizeLinear)
# 14  stepsizeLinear                   6  Delete Low Frequency (stepsizeLinear)
# 20  stepsizeLinear                   1  Delete Low Frequency (stepsizeLinear)
# 22  stepsizeLinear                   2  Delete Low Frequency (stepsizeLinear)
# 24  stepsizeLinear                   3  Delete Low Frequency (stepsizeLinear)
# 26  stepsizeLinear                   4  Delete Low Frequency (stepsizeLinear)
# 28  stepsizeLinear                   5  Delete Low Frequency (stepsizeLinear)
# 30  stepsizeLinear                   6  Delete Low Frequency (stepsizeLinear)
# 36  stepsizeLinear                   1  Delete Low Frequency (stepsizeLinear)
# 38  stepsizeLinear                   2  Delete Low Frequency (stepsizeLinear)
# 40  stepsizeLinear                   3  Delete Low Frequency (stepsizeLinear)
# 42  stepsizeLinear                   4  Delete Low Frequency (stepsizeLinear)
# 44  stepsizeLinear                   5  Delete Low Frequency (stepsizeLinear)
# 46  stepsizeLinear                   6  Delete Low Frequency (stepsizeLinear)
# 52  stepsizeLinear                   1  Delete Low Frequency (stepsizeLinear)
# 54  stepsizeLinear                   2  Delete Low Frequency (stepsizeLinear)
# 56  stepsizeLinear                   3  Delete Low Frequency (stepsizeLinear)
# 58  stepsizeLinear                   4  Delete Low Frequency (stepsizeLinear)
# 60  stepsizeLinear                   5  Delete Low Frequency (stepsizeLinear)
# 62  stepsizeLinear                   6  Delete Low Frequency (stepsizeLinear)
# 68  stepsizeLinear                   1  Delete Low Frequency (stepsizeLinear)
# 70  stepsizeLinear                   2  Delete Low Frequency (stepsizeLinear)
# 72  stepsizeLinear                   3  Delete Low Frequency (stepsizeLinear)
# 74  stepsizeLinear                   4  Delete Low Frequency (stepsizeLinear)
# 76  stepsizeLinear                   5  Delete Low Frequency (stepsizeLinear)
# 78  stepsizeLinear                   6  Delete Low Frequency (stepsizeLinear)
# 84  stepsizeLinear                   1  Delete Low Frequency (stepsizeLinear)
# 86  stepsizeLinear                   2  Delete Low Frequency (stepsizeLinear)
# 88  stepsizeLinear                   3  Delete Low Frequency (stepsizeLinear)
# 90  stepsizeLinear                   4  Delete Low Frequency (stepsizeLinear)
# 92  stepsizeLinear                   5  Delete Low Frequency (stepsizeLinear)
# 94  stepsizeLinear                   6  Delete Low Frequency (stepsizeLinear)
#
#            f1
# 4   80.469758
# 6   80.499074
# 8   80.514261
# 10  80.529490
# 12  80.541176
# 14  80.549356
# 20  80.444861
# 22  80.462141
# 24  80.488030
# 26  80.503770
# 28  80.523184
# 30  80.519191
# 36  80.451822
# 38  80.479226
# 40  80.499090
# 42  80.523435
# 44  80.523663
# 46  80.548696
# 52  80.342183
# 54  80.378716
# 56  80.394407
# 58  80.412906
# 60  80.423751
# 62  80.432272
# 68  80.425573
# 70  80.460107
# 72  80.471978
# 74  80.488164
# 76  80.496319
# 78  80.506133
# 84  80.235185
# 86  80.277837
# 88  80.296251
# 90  80.306850
# 92  80.329890
# 94  80.318272
#
# [36 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Config File', 'subjects', 'duration', 'mean', 'meanOfHits', 'median',
#        'stddev', 'top1', 'top5', 'top10', 'topL', 'recall', 'precision',
#        'precisionAtL', 'backoff', 'Condition', 'threshold', 'threshold_float',
#        'merger', 'splitter', 'stepsize', 'Parallel Execution', 'Description',
#        'f1'],
#       dtype='object')

# %%
df[['backoff','Condition', 'threshold', 'threshold_float', 'Parallel Execution']]
# Out:
#                backoff                   Condition  threshold  \
# 0        splitProperty       tooFewRecommendations        1.0
# 1        splitProperty       tooFewRecommendations        1.0
# 2        splitProperty       tooFewRecommendations        1.0
# 3        splitProperty       tooFewRecommendations        1.0
# 4   deleteLowFrequency       tooFewRecommendations        1.0
# ..                 ...                         ...        ...
# 90  deleteLowFrequency  tooUnlikelyRecommendations        3.0
# 91  deleteLowFrequency  tooUnlikelyRecommendations        3.0
# 92  deleteLowFrequency  tooUnlikelyRecommendations        3.0
# 93  deleteLowFrequency  tooUnlikelyRecommendations        3.0
# 94  deleteLowFrequency  tooUnlikelyRecommendations        3.0
#
#     threshold_float  Parallel Execution
# 0               0.0                   2
# 1               0.0                   2
# 2               0.0                   2
# 3               0.0                   2
# 4               0.0                   1
# ..              ...                 ...
# 90              0.1                   4
# 91              0.1                   4
# 92              0.1                   5
# 93              0.1                   5
# 94              0.1                   6
#
# [95 rows x 5 columns]

# %%
plt.figure(figsize=(15,25))
g = sns.relplot(x="recall", y="precisionAtL", hue="Description",style ="Description", size="Parallel Execution",
            sizes=(50, 200), alpha=.7,
            height=6, data=df)

#leg = g._legend
#leg.set_bbox_to_anchor([0.30,0.0])  # coordinates of lower left of bounding box
#leg._loc=8
#plt.subplots_adjust(bottom=0.5, right=0.6)
# plt.show()
plt.savefig("backoff_comp.pdf", bbox_inches='tight')

plt.figure(figsize=(15,25))
g = sns.relplot(x="recall", y="precisionAtL", hue="Condition", style="Condition", size="threshold",
            sizes=(50, 200), alpha=.2,
            height=6, data=df)

#leg = g._legend
#leg.set_bbox_to_anchor([0.7,0.3])  # coordinates of lower left of bounding box

#leg._loc=3
#plt.subplots_adjust(bottom=0, right=0.1)

# plt.show()
plt.savefig("condition_comp.pdf", bbox_inches='tight')

# %%
df[df['precisionAtL']==max(df['precisionAtL'])]
# Out:
#    Config File  subjects  duration    mean  meanOfHits  median   stddev  \
# 2            2     40663   24.8525  3.9176      2.7069     1.0  27.1357
#
#       top1     top5    top10  ...        backoff              Condition  \
# 2  79.1776  93.3601  96.4316  ...  splitProperty  tooFewRecommendations
#
#    threshold  threshold_float merger         splitter  stepsize  \
# 2        1.0              0.0    avg  everySecondItem
#
#    Parallel Execution                           Description         f1
# 2                   2  Split Property (everySecondItem avg)  80.678406
#
# [1 rows x 24 columns]

# %%
df[df['Description']=='Split Property (twoSupportRanges max)']
# Out:
#     Config File  subjects  duration    mean  meanOfHits  median   stddev  \
# 1             1     40663   24.9412  3.5964      2.9118     1.0  22.6400
# 17           17     40663   25.1936  3.5968      2.9122     1.0  22.6036
# 33           33     40663   25.0576  3.5886      2.9040     1.0  22.6015
# 49           49     40663   28.2981  3.6504      2.9659     1.0  22.6319
# 65           65     40663   25.1729  3.5933      2.9087     1.0  22.6081
# 81           81     40663   29.6406  3.6649      2.9804     1.0  22.6657
#
#        top1     top5    top10  ...        backoff                   Condition  \
# 1   79.0129  93.1830  96.3529  ...  splitProperty       tooFewRecommendations
# 17  78.9612  93.1732  96.2915  ...  splitProperty  tooUnlikelyRecommendations
# 33  79.0079  93.1855  96.3210  ...  splitProperty       tooFewRecommendations
# 49  78.8038  92.7551  95.9054  ...  splitProperty  tooUnlikelyRecommendations
# 65  78.9932  93.1928  96.3308  ...  splitProperty       tooFewRecommendations
# 81  78.7448  92.6838  95.8586  ...  splitProperty  tooUnlikelyRecommendations
#
#     threshold  threshold_float merger          splitter  stepsize  \
# 1         1.0         0.000000    max  twoSupportRanges
# 17        1.0         0.033333    max  twoSupportRanges
# 33        2.0         0.000000    max  twoSupportRanges
# 49        2.0         0.066667    max  twoSupportRanges
# 65        3.0         0.000000    max  twoSupportRanges
# 81        3.0         0.100000    max  twoSupportRanges
#
#     Parallel Execution                            Description         f1
# 1                    2  Split Property (twoSupportRanges max)  80.647379
# 17                   2  Split Property (twoSupportRanges max)  80.627810
# 33                   2  Split Property (twoSupportRanges max)  80.645903
# 49                   2  Split Property (twoSupportRanges max)  80.494229
# 65                   2  Split Property (twoSupportRanges max)  80.641761
# 81                   2  Split Property (twoSupportRanges max)  80.443993
#
# [6 rows x 24 columns]

# %%
df[df['duration']<26].sort_values('precisionAtL', ascending=False).drop_duplicates(['Description'])
# Out:
#     Config File  subjects  duration    mean  meanOfHits  median   stddev  \
# 2             2     40663   24.8525  3.9176      2.7069     1.0  27.1357
# 64           64     40663   24.9193  3.9297      2.7190     1.0  27.1494
# 7             7     40663   24.8553  3.8081      2.8055     1.0  25.4850
# 12           12     40663   25.8503  4.9539      2.7036     1.0  35.3375
# 1             1     40663   24.9412  3.5964      2.9118     1.0  22.6400
# 35           35     40663   25.1123  3.5999      2.9153     1.0  22.6287
#
#        top1     top5    top10  ...             backoff              Condition  \
# 2   79.1776  93.3601  96.4316  ...       splitProperty  tooFewRecommendations
# 64  79.1383  93.3010  96.4046  ...       splitProperty  tooFewRecommendations
# 7   79.0547  93.2814  96.3702  ...  deleteLowFrequency  tooFewRecommendations
# 12  79.0620  93.2150  96.2693  ...  deleteLowFrequency  tooFewRecommendations
# 1   79.0129  93.1830  96.3529  ...       splitProperty  tooFewRecommendations
# 35  79.0055  93.2051  96.2988  ...       splitProperty  tooFewRecommendations
#
#     threshold  threshold_float merger          splitter              stepsize  \
# 2         1.0              0.0    avg   everySecondItem
# 64        3.0              0.0    max   everySecondItem
# 7         1.0              0.0                           stepsizeProportional
# 12        1.0              0.0                                 stepsizeLinear
# 1         1.0              0.0    max  twoSupportRanges
# 35        2.0              0.0    avg  twoSupportRanges
#
#     Parallel Execution                                  Description         f1
# 2                    2         Split Property (everySecondItem avg)  80.678406
# 64                   2         Split Property (everySecondItem max)  80.672158
# 7                    2  Delete Low Frequency (stepsizeProportional)  80.631517
# 12                   5        Delete Low Frequency (stepsizeLinear)  80.541176
# 1                    2        Split Property (twoSupportRanges max)  80.647379
# 35                   2        Split Property (twoSupportRanges avg)  80.646756
#
# [6 rows x 24 columns]
